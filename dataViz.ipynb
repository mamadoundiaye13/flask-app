# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
# table_mn = liste de tous les tableaux de page: 
langa_PROG = pd. read_html('https://fr.wikipedia.org/wiki/Chronologie_des_langages_de_programmation#')

# %%
frames = []
for i  in range(len(langa_PROG)):
    frames.append(langa_PROG[i])
    
df = pd.concat(frames)
df = df.drop(df.index[0])
df
# Out:
#    Années               Langage                Promoteur        Inspiration
# 1    1936  Machine de Turing[1]              Alan Turing                NaN
# 2    1945            Plankalkül              Konrad Zuse                NaN
# 1    1954       Mark I Autocode             Tony Brooker                NaN
# 2    1954               FORTRAN              John Backus                A-0
# 3    1954           ARITH-MATIC             Grace Hopper                A-0
# ..    ...                   ...                      ...                ...
# 3    2011                Kotlin                JetBrains                NaN
# 4    2011                Ceylon                   RedHat               Java
# 5    2012                   Elm  Elm Software Foundation            Haskell
# 6    2014                 Swift                    Apple        Objective C
# 7    2017              ReasonML                 Facebook  OCAML, JavaScript
#
# [148 rows x 4 columns]

# %%
hist = df.hist(bins=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c111e544baa8> in <module>
# ----> 1 hist = df.hist(bins=3)
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     413
#     414     if naxes == 0:
# --> 415         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     416
#     417     fig, axes = _subplots(
#
# ValueError: hist method requires numerical columns, nothing to plot.

# %%
#df_total.plot.scatter(x='Années', y="Langage", c = "Inspiration")

# %% [markdown]
# # dictionnaire

# %%
#df_total[["Années", "Langage"]].cumsum(0).head()
# Out:
#    Années                                            Langage
# 1    1954                                    Mark I Autocode
# 2    3908                             Mark I AutocodeFORTRAN
# 3    5862                  Mark I AutocodeFORTRANARITH-MATIC
# 4    7816        Mark I AutocodeFORTRANARITH-MATICMATH-MATIC
# 5    9771  Mark I AutocodeFORTRANARITH-MATICMATH-MATICFLO...

# %%
df_total.columns
# Out:
# Index(['Années', 'Langage', 'Inspiration', 'Promoteur'], dtype='object')

# %%
df_total.head()
# Out:
#    Années          Langage Inspiration     Promoteur
# 1    1954  Mark I Autocode         NaN  Tony Brooker
# 2    1954          FORTRAN         A-0   John Backus
# 3    1954      ARITH-MATIC         A-0  Grace Hopper
# 4    1954       MATH-MATIC         A-0  Grace Hopper
# 5    1955       FLOW-MATIC         A-0  Grace Hopper

# %%
#df_total.groupby(['Années',"Langage"]).mean().astype('float')

# %%
#pd.merge(df_total,on="Années")

# %%
#df_total = df_total.unstack(level=0)

# %%
df_total
# Out:
#     Années          Langage        Inspiration                Promoteur
# 1     1954  Mark I Autocode                NaN             Tony Brooker
# 2     1954          FORTRAN                A-0              John Backus
# 3     1954      ARITH-MATIC                A-0             Grace Hopper
# 4     1954       MATH-MATIC                A-0             Grace Hopper
# 5     1955       FLOW-MATIC                A-0             Grace Hopper
# ..     ...              ...                ...                      ...
# 3     2011           Kotlin                NaN                JetBrains
# 4     2011           Ceylon               Java                   RedHat
# 5     2012              Elm            Haskell  Elm Software Foundation
# 6     2014            Swift        Objective C                    Apple
# 7     2017         ReasonML  OCAML, JavaScript                 Facebook
#
# [146 rows x 4 columns]

# %%
df_total.head()
#df_total=df_total.reindex(Années)
# Out:
#    Années          Langage Inspiration     Promoteur
# 1    1954  Mark I Autocode         NaN  Tony Brooker
# 2    1954          FORTRAN         A-0   John Backus
# 3    1954      ARITH-MATIC         A-0  Grace Hopper
# 4    1954       MATH-MATIC         A-0  Grace Hopper
# 5    1955       FLOW-MATIC         A-0  Grace Hopper

# %%
#df_total=df_total.reindex(Années)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_total.plot(kind='line', subplots=False)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df_total.plot()
# Out:
# <AxesSubplot:>

# %%
# je veux plot juste la colonne langage
df_total["Années"].plot()
# Out:
# <AxesSubplot:>

# %%
df_total.plot.scatter(x="Années", y ="Langage",alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Années', ylabel='Langage'>

# %%
df.plot.scatter(x="Langage", y ="Années",alpha=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-6a56be75e811> in <module>
# ----> 1 df.plot.scatter(x="Langage", y ="Années",alpha=1)
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1611             ...                       colormap='viridis')
#    1612         """
# -> 1613         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1614
#    1615     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     892         if kind in self._dataframe_kinds:
#     893             if isinstance(data, ABCDataFrame):
# --> 894                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     895             else:
#     896                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1008         else:
#    1009             label = None
# -> 1010         scatter = ax.scatter(
#    1011             data[x].values,
#    1012             data[y].values,
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4430         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
#    4431
# -> 4432         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
#    4433         x = self.convert_xunits(x)
#    4434         y = self.convert_yunits(y)
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2188
#    2189         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2190         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2191         return kwargs
#    2192
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2170                 # We only need to update if there is nothing set yet.
#    2171                 if not axis.have_units():
# -> 2172                     axis.update_units(data)
#    2173
#    2174             # Check for units in the kwargs, and if present update axis
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/axis.py in update_units(self, data)
#    1461         neednew = self.converter != converter
#    1462         self.converter = converter
# -> 1463         default = self.converter.default_units(data, self)
#    1464         if default is not None and self.units is None:
#    1465             self.set_units(default)
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/category.py in __init__(self, data)
#     174         self._counter = itertools.count()
#     175         if data is not None:
# --> 176             self.update(data)
#     177
#     178     @staticmethod
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/category.py in update(self, data)
#     209         for val in OrderedDict.fromkeys(data):
#     210             # OrderedDict just iterates over unique values in data.
# --> 211             cbook._check_isinstance((str, bytes), value=val)
#     212             if convertible:
#     213                 # this will only be called so long as convertible is True.
#
# ~/Projects/IPSSI/API_Web_Scrpping/project_flask/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _check_isinstance(_types, **kwargs)
#    2244     for k, v in kwargs.items():
#    2245         if not isinstance(v, types):
# -> 2246             raise TypeError(
#    2247                 "{!r} must be an instance of {}, not a {}".format(
#    2248                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a int

# %%
df_total.plot.box()
# Out:
# <AxesSubplot:>

# %%
# faire pr chaque colonne separement
axs = df_total.plot.area(figsize=(12,4), subplots=True)

# %%
import seaborn as sns

# %%
#pip install seaborn

# %%
#df_total=df_total.groupby(['Années','Langage']).size()
#df_total=df_total.unstack()
#df_total.plot(kind='bar')

# %%
plt.style.use('ggplot')
df_total.groupby(['Années','Langage']).Langage.count().unstack().plot.bar(legend=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
